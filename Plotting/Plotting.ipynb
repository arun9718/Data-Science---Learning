# %% [markdown]
# <a href="https://colab.research.google.com/github/arun9718/Data-Science---Learning/blob/Day4/Plotting/Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[4,5,6]

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,marker='D',linestyle=' ')
plt.show()

# %%
plt.plot(x,y,marker='D',linestyle='dashed',color='red')
plt.show()

# %%
plt.plot(x,y,marker='*',linestyle='dashed',ms=30,mfc='red',mec='black',linewidth=3)
plt.show()
